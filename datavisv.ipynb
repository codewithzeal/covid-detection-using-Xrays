# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
img1 = cv.imread('covidDataset/train/covid/1-s2.0-S0929664620300449-gr2_lrg-d.jpg',0)
img2 = cv.imread('covidDataset2/train/covid/1-s2.0-S0929664620300449-gr2_lrg-d.jpg',0)
img3 = cv.imread('covidDataset3/train/covid/1-s2.0-S0929664620300449-gr2_lrg-d.jpg',0)
img4 = cv.imread('covidDataset4/train/covid/1-s2.0-S0929664620300449-gr2_lrg-d.jpg',0)
img5 = cv.imread('covidDataset5/train/covid/1-s2.0-S0929664620300449-gr2_lrg-d.jpg',0)
img6 = cv.imread('covidDataset6/train/covid/1-s2.0-S0929664620300449-gr2_lrg-d.jpg',0)
img7=cv.imread('covidDataset7/train/covid/1-s2.0-S0929664620300449-gr2_lrg-d.jpg',0)
fig = plt.figure(figsize=(24, 16))
ax1 = fig.add_subplot(2,3,1)
ax1.imshow(img1, cmap='gray')
ax1.title.set_text('Orignal data')
ax2 = fig.add_subplot(2,3,2)
ax2.imshow(img2, cmap='gray')
ax2.title.set_text('CLAHE')
ax3 = fig.add_subplot(2,3,3)
ax3.imshow(img3, cmap='gray')
ax3.title.set_text('orignal+SMOOTHING')
ax4 = fig.add_subplot(2,3,4)
ax4.imshow(img4, cmap='gray')
ax4.title.set_text('clahe+SMOOTHING')
ax5 = fig.add_subplot(2,3,5)
ax5.imshow(img5, cmap='gray')
ax5.title.set_text('CLAHE denoised')
ax6 = fig.add_subplot(2,3,6)
ax6.imshow(img6, cmap='gray')
ax6.title.set_text('orignal denoised')
plt.show()
